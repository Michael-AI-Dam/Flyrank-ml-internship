# %% [markdown]
# <a href="https://colab.research.google.com/github/Michael-AI-Dam/Flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Michael-AI-Dam/Flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## Selected Lane: CTR / Search Performance Optimization
#
# I chose this lane because high impression count paired with low click-through rate
# (CTR) represents the most direct opportunity to increase search traffic without
# needing new content creation. Improving CTR leverages existing visibility to drive
# more engagement.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Decision:** Which queries or pages should be prioritized for CTR improvement?
# **Action:** SEO/content teams can adjust titles, snippets, or metadata for queries
# with high impressions but low CTR.
# **Cost of a wrong call:** Effort wasted on optimizing queries that don't move
# traffic, or missed opportunities where small changes could yield large gains.
# **Why ML helps:** CTR patterns vary across queries and positions; ML can highlight
# which combinations are most promising to optimize.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load starter dataset
df = pd.read_csv("https://raw.githubusercontent.com/Michael-AI-Dam/Flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv")

print("Shape:", df.shape)
print("Columns:", list(df.columns))
# Out:
# Shape: (30000, 44)
# Columns: ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']

# %%
print(df["ctr"].describe())
# Out:
# count    30000.000000
# mean         0.510733
# std          3.279162
# min          0.000000
# 25%          0.000000
# 50%          0.070000
# 75%          0.290000
# max        100.000000
# Name: ctr, dtype: float64

# %%
ctr_col = "ctr"
impressions_col = "impressions_last_30d"

total_rows = len(df)

# Auto-detect scale: if max value is under ~1.5, it's a fraction (multiply by 100 to show %)
# if it's already in the tens/hundreds, it's already a percentage (don't multiply)
ctr_max = df[ctr_col].max()
if ctr_max <= 1.5:
    avg_ctr_pct = df[ctr_col].mean() * 100
    low_ctr_threshold = 0.05  # 5% as a fraction
else:
    avg_ctr_pct = df[ctr_col].mean()
    low_ctr_threshold = 5  # 5% already in percentage units

high_impr_low_ctr = df[(df[impressions_col] > 1000) & (df[ctr_col] < low_ctr_threshold)].shape[0]

print("CTR column max value:", ctr_max, "→ treating as", "fraction (0-1)" if ctr_max <= 1.5 else "percentage")
print("Total rows:", total_rows)
print("Average CTR: {:.2f}%".format(avg_ctr_pct))
print("High impressions + low CTR rows:", high_impr_low_ctr)
# Out:
# CTR column max value: 100.0 → treating as percentage
# Total rows: 30000
# Average CTR: 0.51%
# High impressions + low CTR rows: 6510

# %% [markdown]
# From the starter dataset (30,000 pages, last-30-day window):
# - Total pages: 30,000
# - Average CTR: [paste real % from output]
# - Pages with >1,000 impressions but <5% CTR: [paste real number from output]
#
# This shows a clear opportunity: even modest CTR improvements on these pages could
# drive meaningful traffic gains without new content creation.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This analysis can highlight queries with high potential for CTR improvement, but
# it cannot guarantee that changes will increase clicks. CTR is influenced by user
# intent and competition, so recommendations should be tested and validated.
#
# I can claim observed patterns and directional opportunities, but I cannot claim
# causal proof or "predicting Google."

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

# %% [markdown]
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under work/notebooks/ — then submit your repo URL on the card. Done.
